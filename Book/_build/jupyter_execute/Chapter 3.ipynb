# %% [markdown]
# # Chapter 3
#
# This is a Jupyter Notebook. This notebook contains sample Python codes.

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
L = [1, 2, 3]
sum = 0 
for num in L:
    sum = sum + num
print('Sum =', sum)
# Out:
# Sum = 6
